# %%
x = 1234

# 21 12

# if x <0 False
# if x % 10 == 0 False
rev = 0
while x > 0:
    rev = rev*10 + x%10
#     print(rev)
    x = x//10
    print(x)

# print(x, rev//10)
# print((x == rev) |(x == rev//10))

# False | True
print(rev)
# Out:
# 123
# 12
# 1
# 0
# 4321

# %%
x = 1234

rev = 0
while x > 0:
    rev = rev*10 + x%10
    x = x//10
    
print(rev)

# rev*10 + x%10
# Out:
# 4321
