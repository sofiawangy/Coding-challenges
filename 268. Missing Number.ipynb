# %%
def missingNumber(nums):
    """
    :type nums: List[int]
    :rtype: int
    """
    expected_sum = len(nums)*(len(nums)+1)//2
    actual_sum = sum(nums)

    return expected_sum - actual_sum

# %%
missingNumber([6,4,2,3,5,7,0,1,9])
# Out:
# 9
# 45
# 37
# 8
