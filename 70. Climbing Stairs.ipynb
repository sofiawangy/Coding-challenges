# %%
def test(n):
    curr = 2
    prev = 1
    
    if n == 1:
        return prev
    if n == 2:
        return curr
    
    for _ in range(2, n):
        curr, prev = curr + prev, curr
    
    return curr
        
test(6)
# Out:
# 13

# %%
for i in range(2,3):
    print(i)
# Out:
# 2
