# %%
prices = [7,1,5,3,6,4]

min_price = float('inf')
max_profit = 0

for p in prices:
    min_price = min(min_prices, p)
    profit = p - min_price
    max_profit = max(max_profit, profit)
# Out:
# inf
